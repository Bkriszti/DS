# %%
url='https://www.olx.ro/auto-masini-moto-ambarcatiuni/autoturisme/?page=1'

# %%
import requests
from bs4 import BeautifulSoup # this module helps in web scrapping.

# %%
data=requests.get(url).text

# %%
soup=BeautifulSoup(data,'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width,initial-scale=1,maximum-scale=1,shrink-to-fit=no" name="viewport"/>\n  <meta content="#f9f9f9" name="theme-color"/>\n  <meta content="6b724926_5003775" name="version"/>\n  <meta content="yes" name="mobile-web-app-capable"/>\n  <meta content="yes" name="apple-mobile-web-app-capable"/>\n  <link href="/app/static/manifest/ro/manifest.json" rel="manifest"/>\n  <title data-react-helmet="true">\n   Autoturisme second hand si noi de vanzare \' Anunturi \' OLX.ro\n  </title>\n  <meta content="ro" data-react-helmet="true" http-equiv="Content-Language"/>\n  <meta content="index, follow" data-react-helmet="true" name="robots"/>\n  <meta content="utta8z7t7kl5b55w23d2o36o0ptzo5" data-react-helmet="true" name="facebook-domain-verification"/>\n  <meta content="ro.mercador://" data-react-helmet="true" property="al:android:url"/>\n  <meta content="ro.mercador" data-react-helmet="true" property="al:androi
# ...

# %%
ds=soup.find_all('div',class_='css-1sw7q4x')

# %%
len(ds)
lm=[]

# %%
for index in range(1,53):
    lm.append(ds[index].find('h6',class_='css-16v5mdi er34gjf0').text)

# %%
lm
# Out:
# ['BMW X5 xDrive25d / Distributie schimbata / Posibilitate Rate Auto',
#  'Bmw 320 D, F30 LCI, facelift, cutie automata, impecabila',
#  'Mercedes-Benz S Mercedes S400D 4matic Airmatic Amg pack 41.000km',
#  'Golf 5 1.9 TDI defect',
#  'Mercedes-Benz Class B',
#  'Ford Mondeo 2008',
#  'Vând Audi A4 2.0 TDI pachet S Line',
#  'Ford Ranger 2013',
#  'De Vânzare Volkswagen Passat B7',
#  'Toyota Land Cruiser 3.0D 2006',
#  'Vand VW GOLF Comfortline 1.0 TSI DSG 7',
#  'Vand Golf 5 acte la zi',
#  'Seat Leon Seat Leon ST FR 2.0 TDI 150 CP',
#  'Tiguan•Virtual•Side•Lane•Front•Dynaudio•MATRIX•Head-up•360•Pano•Piel',
#  'Audi A6 istoric complet / km reali / rate',
#  'Mercedes-Benz S Mercedes Benz S400d Limuzina 4MATIC',
#  'Audi A3 Posibilitate Rate / Km Certificat / Garantie Extinsa',
#  'Jeep Grand Cherokee 3.0 CRD',
#  'Ford Focus Ford Focus EcoBoost// Euro 6// Manual// Volan incalzit// TVA INCLUS!',
#  'BMW X5 M Facelift xDrive 3.0 Diesel 235 Cp 2013 Automat',
# ...
